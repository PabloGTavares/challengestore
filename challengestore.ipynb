# %% [markdown]
# # Alura Store Brasil
#
# ## Problema de negócio:
# Você foi contratado como pessoa analista de dados para ajudar Sr. João a decidir **qual loja ele deve vender.**
#
# O Sr. João tem uma rede de quatro lojas, que pertencem ao e-commerce Alura Store. Ele quer vender uma dessas lojas para ter um capital e investir em um novo negócio.
#
# Você, como pessoa analista de dados, vai **analisar qual dessas lojas tem o menor desempenho comparado às outras e, baseado nisso, fazer um relatório e mostrar para Sr.João qual loja ele deve vender.**
#
# Para isso, você vai analisar as seguintes métricas: `faturamento total de cada loja`, `categorias mais populares`, `média de avaliação dos clientes`, `produtos mais e menos vendidos` e `custo médio do frete`.
#
# Com essas métricas, você será capaz de decidir qual loja Sr.João deve vender.
#
# ---

# %% [markdown]
# # Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# 1    cartao_credito                       4 -22.25 -42.66
# 2    cartao_credito                       1 -15.83 -47.86
# 3            boleto                       1 -30.17 -53.50
# 4            boleto                       1 -18.10 -44.38

# %% [markdown]
# # 0. Análise inicial dos dados

# %% [markdown]
# ## Análise das colunas
#
# Vamos verificar se as lojas possuem nomes de colunas diferentes e se possuem dados nulos.

# %%
loja.columns
# Out:
# Index(['Produto', 'Categoria do Produto', 'Preço', 'Frete', 'Data da Compra',
#        'Vendedor', 'Local da compra', 'Avaliação da compra',
#        'Tipo de pagamento', 'Quantidade de parcelas', 'lat', 'lon'],
#       dtype='object')

# %%
loja2.columns
# Out:
# Index(['Produto', 'Categoria do Produto', 'Preço', 'Frete', 'Data da Compra',
#        'Vendedor', 'Local da compra', 'Avaliação da compra',
#        'Tipo de pagamento', 'Quantidade de parcelas', 'lat', 'lon'],
#       dtype='object')

# %%
loja3.columns
# Out:
# Index(['Produto', 'Categoria do Produto', 'Preço', 'Frete', 'Data da Compra',
#        'Vendedor', 'Local da compra', 'Avaliação da compra',
#        'Tipo de pagamento', 'Quantidade de parcelas', 'lat', 'lon'],
#       dtype='object')

# %%
loja4.columns
# Out:
# Index(['Produto', 'Categoria do Produto', 'Preço', 'Frete', 'Data da Compra',
#        'Vendedor', 'Local da compra', 'Avaliação da compra',
#        'Tipo de pagamento', 'Quantidade de parcelas', 'lat', 'lon'],
#       dtype='object')

# %% [markdown]
# > As lojas possuem as colunas com mesmo nome.
# ---

# %%
loja.isnull().sum()
# Out:
# Produto                   0
# Categoria do Produto      0
# Preço                     0
# Frete                     0
# Data da Compra            0
# Vendedor                  0
# Local da compra           0
# Avaliação da compra       0
# Tipo de pagamento         0
# Quantidade de parcelas    0
# lat                       0
# lon                       0
# dtype: int64

# %%
loja2.isnull().sum()
# Out:
# Produto                   0
# Categoria do Produto      0
# Preço                     0
# Frete                     0
# Data da Compra            0
# Vendedor                  0
# Local da compra           0
# Avaliação da compra       0
# Tipo de pagamento         0
# Quantidade de parcelas    0
# lat                       0
# lon                       0
# dtype: int64

# %%
loja4.isnull().sum()
# Out:
# Produto                   0
# Categoria do Produto      0
# Preço                     0
# Frete                     0
# Data da Compra            0
# Vendedor                  0
# Local da compra           0
# Avaliação da compra       0
# Tipo de pagamento         0
# Quantidade de parcelas    0
# lat                       0
# lon                       0
# dtype: int64

# %% [markdown]
# > Não há valores nulos nas lojas.
# ---

# %% [markdown]
# ## Análise estatística dos dados

# %%
loja.describe()
# Out:
#              Preço        Frete  Avaliação da compra  Quantidade de parcelas  \
# count  2359.000000  2359.000000          2359.000000             2359.000000
# mean    650.491361    34.691805             3.976685                2.943196
# std     819.582778    43.814183             1.415370                2.819897
# min      10.070000     0.000000             1.000000                1.000000
# 25%      74.345000     4.141783             3.000000                1.000000
# 50%     313.750000    16.498835             5.000000                1.000000
# 75%     904.130000    48.050074             5.000000                4.000000
# max    3969.380000   214.377060             5.000000               24.000000
#
#                lat          lon
# count  2359.000000  2359.000000
# mean    -20.763366   -47.349385
# std       5.372400     4.183180
# min     -30.170000   -70.550000
# 25%     -22.250000   -48.790000
# 50%     -22.190000   -48.790000
# 75%     -18.100000   -44.380000
# max       1.410000   -36.590000

# %%
loja2.describe()
# Out:
#              Preço        Frete  Avaliação da compra  Quantidade de parcelas  \
# count  2359.000000  2359.000000          2359.000000             2359.000000
# mean    630.970352    33.621941             4.037304                2.902501
# std     794.078997    42.321932             1.356153                2.848416
# min      10.160000     0.000000             1.000000                1.000000
# 25%      72.730000     3.904020             4.000000                1.000000
# 50%     290.960000    15.406740             5.000000                1.000000
# 75%     903.580000    47.250196             5.000000                4.000000
# max    3937.850000   216.707633             5.000000               24.000000
#
#                lat          lon
# count  2359.000000  2359.000000
# mean    -20.473243   -47.098508
# std       5.321015     4.169111
# min     -30.170000   -70.550000
# 25%     -22.250000   -48.790000
# 50%     -22.190000   -48.790000
# 75%     -18.100000   -44.380000
# max       1.990000   -36.590000

# %%
loja3.describe()
# Out:
#              Preço        Frete  Avaliação da compra  Quantidade de parcelas  \
# count  2359.000000  2359.000000          2359.000000             2359.000000
# mean    620.612560    33.074464             4.048326                2.967783
# std     774.191691    41.260516             1.386426                2.812153
# min      10.080000     0.000000             1.000000                1.000000
# 25%      76.560000     4.149261             4.000000                1.000000
# 50%     301.670000    15.879702             5.000000                2.000000
# 75%     888.040000    46.635503             5.000000                4.000000
# max    3957.620000   211.257624             5.000000               24.000000
#
#                lat          lon
# count  2359.000000  2359.000000
# mean    -20.405396   -47.129233
# std       5.465572     4.197520
# min     -30.170000   -70.550000
# 25%     -22.250000   -48.790000
# 50%     -22.190000   -48.790000
# 75%     -18.100000   -44.380000
# max       1.990000   -36.590000

# %%
loja4.describe()
# Out:
#              Preço        Frete  Avaliação da compra  Quantidade de parcelas  \
# count  2358.000000  2358.000000          2358.000000             2358.000000
# mean    587.149101    31.278997             3.995759                2.896098
# std     758.341290    40.373136             1.403063                2.730393
# min      10.170000     0.000000             1.000000                1.000000
# 25%      71.225000     3.847061             3.000000                1.000000
# 50%     279.315000    14.614197             5.000000                1.000000
# 75%     845.577500    44.438533             5.000000                4.000000
# max    3869.560000   206.325555             5.000000               18.000000
#
#                lat          lon
# count  2358.000000  2358.000000
# mean    -20.494215   -47.107553
# std       5.433033     4.159156
# min     -30.170000   -65.100000
# 25%     -22.250000   -48.790000
# 50%     -22.190000   -48.790000
# 75%     -18.100000   -44.380000
# max       1.410000   -36.590000

# %% [markdown]
# > Com essa análise estatística inicial com describe, podemos tirar insights quanto à grandeza do Frete e do Preço dos produtos.
#
# > Ambos estão em reais normais, ou seja, não estão com seus valores na escala de milhões ou bilhões, mesmo com uma grande quantidade de números após o ponto flutuante.

# %% [markdown]
# ---
#
# ## Análise dos métodos de pagamento usados pelos clientes

# %%
loja.columns
# Out:
# Index(['Produto', 'Categoria do Produto', 'Preço', 'Frete', 'Data da Compra',
#        'Vendedor', 'Local da compra', 'Avaliação da compra',
#        'Tipo de pagamento', 'Quantidade de parcelas', 'lat', 'lon'],
#       dtype='object')

# %%
print('Métodos de Pagamento - Loja 1', loja['Tipo de pagamento'].unique())
print('Métodos de Pagamento - Loja 2', loja2['Tipo de pagamento'].unique())
print('Métodos de Pagamento - Loja 3', loja3['Tipo de pagamento'].unique())
print('Métodos de Pagamento - Loja 4', loja4['Tipo de pagamento'].unique())
# Out:
# Métodos de Pagamento - Loja 1 ['cartao_credito' 'boleto' 'cupom' 'cartao_debito']
# Métodos de Pagamento - Loja 2 ['boleto' 'cartao_credito' 'cupom' 'cartao_debito']
# Métodos de Pagamento - Loja 3 ['cartao_credito' 'boleto' 'cupom' 'cartao_debito']
# Métodos de Pagamento - Loja 4 ['cartao_credito' 'boleto' 'cupom' 'cartao_debito']

# %%
loja['Tipo de pagamento'].value_counts()
# Out:
# Tipo de pagamento
# cartao_credito    1704
# boleto             483
# cupom              137
# cartao_debito       35
# Name: count, dtype: int64

# %%
loja2['Tipo de pagamento'].value_counts()
# Out:
# Tipo de pagamento
# cartao_credito    1721
# boleto             467
# cupom              141
# cartao_debito       30
# Name: count, dtype: int64

# %%
loja3['Tipo de pagamento'].value_counts()
# Out:
# Tipo de pagamento
# cartao_credito    1753
# boleto             468
# cupom              101
# cartao_debito       37
# Name: count, dtype: int64

# %%
loja4['Tipo de pagamento'].value_counts()
# Out:
# Tipo de pagamento
# cartao_credito    1720
# boleto             482
# cupom              125
# cartao_debito       31
# Name: count, dtype: int64

# %% [markdown]
# #### Em todas as quatro lojas, predominam as vendas com o método de pagamento `cartão de crédito`, com mais de 1000 vendas com cartão de crédito em todas as lojas.
#
# ---

# %% [markdown]
# # 1. Análise do faturamento

# %% [markdown]
# ## Calculando o faturamento das lojas

# %%
faturamento_loja1 = loja.Preço.sum()
faturamento_loja2 = loja2.Preço.sum()
faturamento_loja3 = loja3.Preço.sum()
faturamento_loja4 = loja4.Preço.sum()

# %%
print(f'''FATURAMENTOS
        Loja 1: {faturamento_loja1},
        Loja 2: {faturamento_loja2},
        Loja 3: {faturamento_loja3},
        Loja 4: {faturamento_loja4}''')
# Out:
# FATURAMENTOS
#         Loja 1: 1534509.12,
#         Loja 2: 1488459.06,
#         Loja 3: 1464025.03,
#         Loja 4: 1384497.58

# %% [markdown]
# ## Visualizando o faturamento com um gráfico de barras interativo
#
# Vamos fazer a visualização com gráficos interativos, permitindo uma visualização mais viva e dinâmica dos dados
#
# Nesse contexto de comparação de faturamento das lojas, vamos utilizar um gráfico de barras verticais, pois o mesmo facilita a visualização de quanto cada loja vendeu e permite uma comparação rápida com uma simples observação.

# %%
import plotly.express as px

dados = pd.DataFrame(
        {'Lojas': ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4'],
        'Faturamento': [faturamento_loja1, faturamento_loja2, faturamento_loja3, faturamento_loja4]}
)

dados['Faturamento em Milhões'] = dados['Faturamento']/1000000

fig = px.bar(dados, x='Lojas',
             y='Faturamento em Milhões',
             title='Faturamento por loja (em R$)',
             color='Lojas',
             text='Faturamento em Milhões'
            )

fig.update_traces(
    texttemplate='R$ %{text:.3f}M'
)

fig.show()

# %% [markdown]
# # 2. Vendas por Categoria

# %% [markdown]
# ## Unificando as lojas em um único dataframe
#
# Vamos agora unificar as lojas para um único dataframe, para então calcular a média específica para cada uma a partir de seu id.
#
# Como as colunas possuem a mesma estrutura, a concatenação torna-se uma excelente opção para unificá-las a fim da realização das nossas próximas análises.

# %% [markdown]
# ### Criando uma coluna de ID's

# %%
loja['ID da Loja'] = 'Loja 01'
loja2['ID da Loja'] = 'Loja 02'
loja3['ID da Loja'] = 'Loja 03'
loja4['ID da Loja'] = 'Loja 04'

# %% [markdown]
# ### Concatenando as colunas

# %%
lojas = pd.concat([loja, loja2, loja3, loja4], ignore_index=True)
lojas
# Out:
#                     Produto   Categoria do Produto    Preço      Frete  \
# 0        Assistente virtual            eletronicos   219.08   9.249790
# 1            Mesa de jantar                 moveis   256.35  11.234305
# 2         Jogo de tabuleiro             brinquedos   279.51  21.262681
# 3               Micro-ondas       eletrodomesticos  1009.99  54.667344
# 4     Cadeira de escritório                 moveis   446.99  26.964689
# ...                     ...                    ...      ...        ...
# 9430         Mesa de jantar                 moveis   303.60  16.852799
# 9431  Cadeira de escritório                 moveis   456.02  24.812798
# 9432           Copo térmico        esporte e lazer    48.99   3.139675
# 9433        Jogo de panelas  utilidades domesticas   202.45  11.062979
# 9434         Corda de pular        esporte e lazer    14.89   1.732696
#
#      Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0        16/01/2021     Pedro Gomes              SP                    4
# 1        18/05/2022  Beatriz Moraes              RJ                    1
# 2        15/03/2021      João Souza              DF                    1
# 3        03/05/2022      João Souza              RS                    4
# 4        07/11/2020   Larissa Alves              MG                    5
# ...             ...             ...             ...                  ...
# 9430     12/02/2020  Camila Ribeiro              RJ                    5
# 9431     17/05/2022   Felipe Santos              PE                    5
# 9432     03/05/2022  Camila Ribeiro              SP                    5
# 9433     15/06/2020   Bianca Santos              PR                    5
# 9434     17/11/2021   Felipe Santos              SP                    5
#
#      Tipo de pagamento  Quantidade de parcelas    lat    lon ID da Loja
# 0       cartao_credito                       8 -22.19 -48.79    Loja 01
# 1       cartao_credito                       4 -22.25 -42.66    Loja 01
# 2       cartao_credito                       1 -15.83 -47.86    Loja 01
# 3               boleto                       1 -30.17 -53.50    Loja 01
# 4               boleto                       1 -18.10 -44.38    Loja 01
# ...                ...                     ...    ...    ...        ...
# 9430    cartao_credito                       1 -22.25 -42.66    Loja 04
# 9431    cartao_credito                       3  -8.38 -37.86    Loja 04
# 9432    cartao_credito                       1 -22.19 -48.79    Loja 04
# 9433    cartao_credito                       1 -24.89 -51.55    Loja 04
# 9434    cartao_credito                       1 -22.19 -48.79    Loja 04
#
# [9435 rows x 13 columns]

# %% [markdown]
# ## Calculando a quantidade de vendas de cada loja

# %%
lojas.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon ID da Loja
# 0    cartao_credito                       8 -22.19 -48.79    Loja 01
# 1    cartao_credito                       4 -22.25 -42.66    Loja 01
# 2    cartao_credito                       1 -15.83 -47.86    Loja 01
# 3            boleto                       1 -30.17 -53.50    Loja 01
# 4            boleto                       1 -18.10 -44.38    Loja 01

# %%
vendas_categoria_lojas = lojas.groupby('Categoria do Produto')[['ID da Loja']].value_counts().reset_index(name='Quantidade de vendas').sort_values(by='ID da Loja', ascending=False)
vendas_categoria_lojas
# Out:
#      Categoria do Produto ID da Loja  Quantidade de vendas
# 0              brinquedos    Loja 04                   338
# 7        eletrodomesticos    Loja 04                   254
# 21                 livros    Loja 04                   187
# 14        esporte e lazer    Loja 04                   277
# 25                 moveis    Loja 04                   480
# 19  instrumentos musicais    Loja 04                   170
# 9             eletronicos    Loja 04                   451
# 28  utilidades domesticas    Loja 04                   201
# 6        eletrodomesticos    Loja 03                   278
# 8             eletronicos    Loja 03                   451
# 24                 moveis    Loja 03                   499
# 13        esporte e lazer    Loja 03                   277
# 30  utilidades domesticas    Loja 03                   177
# 22                 livros    Loja 03                   185
# 2              brinquedos    Loja 03                   315
# 18  instrumentos musicais    Loja 03                   177
# 27                 moveis    Loja 02                   442
# 29  utilidades domesticas    Loja 02                   181
# 20                 livros    Loja 02                   197
# 16  instrumentos musicais    Loja 02                   224
# 15        esporte e lazer    Loja 02                   275
# 11            eletronicos    Loja 02                   422
# 5        eletrodomesticos    Loja 02                   305
# 3              brinquedos    Loja 02                   313
# 17  instrumentos musicais    Loja 01                   182
# 1              brinquedos    Loja 01                   324
# 23                 livros    Loja 01                   173
# 12        esporte e lazer    Loja 01                   284
# 26                 moveis    Loja 01                   465
# 10            eletronicos    Loja 01                   448
# 4        eletrodomesticos    Loja 01                   312
# 31  utilidades domesticas    Loja 01                   171

# %% [markdown]
# ## Visualizando as vendas por categoria de cada loja
#
# Vamos visualizar as vendas por categoria de cada loja em um único gráfico de barras, agupando as vendas por loja.
# A escolha do gráfico de barras se dá pela facilidade de compreensão e pela quantidade de dados que iremos visualizar.

# %%
fig = px.bar(vendas_categoria_lojas,
             x='ID da Loja',
             y='Quantidade de vendas',
             color='Categoria do Produto',
             barmode='group',
             title='Vendas por categoria de produto (todas as lojas)'
            )

fig.update_yaxes(title_text='Quantidade de Vendas')

fig.show()

# %%
fig = px.pie(vendas_categoria_lojas,
             values='Quantidade de vendas',
             names='Categoria do Produto',
             color='Categoria do Produto',
             title='Vendas por categoria de produto (todas as lojas)'
            )

fig.show()

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %% [markdown]
# ## Calculando a média de avaliações

# %%
medias_avaliacoes = lojas.groupby('ID da Loja')['Avaliação da compra'].mean().reset_index().sort_values(by='Avaliação da compra', ascending=False)
medias_avaliacoes
# Out:
#   ID da Loja  Avaliação da compra
# 2    Loja 03             4.048326
# 1    Loja 02             4.037304
# 3    Loja 04             3.995759
# 0    Loja 01             3.976685

# %% [markdown]
# ### Arredondando os valores das médias para 2 casas decimais

# %%
medias_avaliacoes['Avaliação da compra'] = round(medias_avaliacoes['Avaliação da compra'], 2)
medias_avaliacoes
# Out:
#   ID da Loja  Avaliação da compra
# 2    Loja 03                 4.05
# 1    Loja 02                 4.04
# 3    Loja 04                 4.00
# 0    Loja 01                 3.98

# %% [markdown]
# ## Visualizando as médias com gráfico de barras
#
# Assim como nas análises anteriores, vamos utilizar o gráfico de barras para uma melhor visualização. Nesse contexto, além de facilitar na visualização dos dados, vai ser muito útil para comparação entre as médias das lojas

# %%
fig = px.bar(medias_avaliacoes,
       x='ID da Loja',
       y='Avaliação da compra',
       color='ID da Loja',
       title='Média de avaliações de cada loja (de 1 a 5)',
       text='Avaliação da compra'
      )

fig.update_layout(legend_title_text='')
fig.update_yaxes(title_text='Avaliações de 1 a 5')
fig.update_xaxes(title_text='Lojas')

fig.show()

# %% [markdown]
# > Pode-se perceber, com essa visualização, que a Loja 3 possui uma maior avaliação, enquanto a Loja 01, responsável pelo maior faturamento dentre todas as lojas do Sr.João, é que possui pior avaliação.

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
lojas.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon ID da Loja
# 0    cartao_credito                       8 -22.19 -48.79    Loja 01
# 1    cartao_credito                       4 -22.25 -42.66    Loja 01
# 2    cartao_credito                       1 -15.83 -47.86    Loja 01
# 3            boleto                       1 -30.17 -53.50    Loja 01
# 4            boleto                       1 -18.10 -44.38    Loja 01

# %% [markdown]
# ## Produtos mais vendidos no total
#
# Vamos pegar o total, considerando todas as lojas, dos produtos mais e menos vendidos.

# %%
produtos_mais_vendidos_total = lojas.groupby('Categoria do Produto')['Produto'].value_counts().sort_values(ascending=False).reset_index()
produtos_mais_vendidos_total
# Out:
#      Categoria do Produto                      Produto  count
# 0                  moveis                       Cômoda    210
# 1        eletrodomesticos                  Micro-ondas    206
# 2              brinquedos     Carrinho controle remoto    206
# 3   instrumentos musicais                      Bateria    203
# 4                  moveis                    Cama king    201
# 5                  livros          Modelagem preditiva    200
# 6   utilidades domesticas              Jogo de panelas    200
# 7        eletrodomesticos           Secadora de roupas    200
# 8              brinquedos             Blocos de montar    199
# 9                  moveis                     Cama box    199
# 10            eletronicos             Celular Plus X42    198
# 11  instrumentos musicais                     Pandeiro    197
# 12        esporte e lazer             Bola de basquete    197
# 13                 moveis                Guarda roupas    197
# 14        esporte e lazer                    Bicicleta    196
# 15                 livros     Iniciando em programação    195
# 16            eletronicos                     Smart TV    192
# 17       eletrodomesticos                    Geladeira    191
# 18       eletrodomesticos                  Lava louças    189
# 19  utilidades domesticas                     Faqueiro    189
# 20  instrumentos musicais                       Violão    188
# 21            eletronicos                   Impressora    188
# 22                 moveis                Kit banquetas    188
# 23       eletrodomesticos                        Fogão    187
# 24            eletronicos                TV Led UHD 4K    187
# 25        esporte e lazer                 Copo térmico    187
# 26        esporte e lazer               Corda de pular    186
# 27                 moveis               Mesa de jantar    185
# 28        esporte e lazer                Bola de vôlei    184
# 29                 moveis                Sofá retrátil    182
# 30                 livros      Dashboards com Power BI    181
# 31                 moveis        Cadeira de escritório    181
# 32             brinquedos              Cubo mágico 8x8    180
# 33             brinquedos            Xadrez de madeira    180
# 34            eletronicos                  Tablet ABXY    179
# 35       eletrodomesticos           Lavadora de roupas    176
# 36             brinquedos            Jogo de tabuleiro    175
# 37             brinquedos                  Boneca bebê    175
# 38             brinquedos               Dinossauro Rex    175
# 39                 moveis               Mesa de centro    175
# 40            eletronicos               Fone de ouvido    174
# 41  utilidades domesticas            Panela de pressão    172
# 42            eletronicos                   Smartwatch    172
# 43  utilidades domesticas                Jogo de copos    169
# 44                 moveis                     Poltrona    168
# 45            eletronicos           Assistente virtual    167
# 46                 livros  Ciência de dados com python    166
# 47  instrumentos musicais                     Guitarra    165
# 48        esporte e lazer                      Mochila    163
# 49            eletronicos                      Headset    158
# 50            eletronicos                 Celular ABXY    157

# %% [markdown]
# ## Categorias com mais vendas

# %%
categorias_mais_vendidas_total = lojas.groupby('Categoria do Produto').size().sort_values(ascending=False).reset_index(name="Quantidade de Vendas")
categorias_mais_vendidas_total
# Out:
#     Categoria do Produto  Quantidade de Vendas
# 0                 moveis                  1886
# 1            eletronicos                  1772
# 2             brinquedos                  1290
# 3       eletrodomesticos                  1149
# 4        esporte e lazer                  1113
# 5  instrumentos musicais                   753
# 6                 livros                   742
# 7  utilidades domesticas                   730

# %% [markdown]
# > Pode-se perceber que as categorias com mais vendas no total são as de *móveis* e *eletrônicos*, com 1886 e 1772 vendas cada, respectivamente. Por outro lado, as categorias com menores vendas são as de *utilidades domésticas*, *livros* e *instrumentos musicais*, com 730, 742 e 753 vendas cada, respectivamente.

# %% [markdown]
# ## Produtos mais vendidos de cada loja, separadamente

# %% [markdown]
# ### Organizando as vendas pelos ID's das lojas

# %%
produtos_mais_vendidos_por_id = lojas.groupby('ID da Loja')[['Produto', 'Categoria do Produto']].value_counts().sort_values(ascending=False).reset_index()

# %%
produtos_mais_vendidos_por_id.rename({"count": "Quantidade de vendas"}, axis=1, inplace=True)
produtos_mais_vendidos_por_id
# Out:
#     ID da Loja                   Produto   Categoria do Produto  \
# 0      Loja 02  Iniciando em programação                 livros
# 1      Loja 02               Micro-ondas       eletrodomesticos
# 2      Loja 04                  Cama box                 moveis
# 3      Loja 02                   Bateria  instrumentos musicais
# 4      Loja 01             TV Led UHD 4K            eletronicos
# ..         ...                       ...                    ...
# 199    Loja 02                Impressora            eletronicos
# 200    Loja 01                   Headset            eletronicos
# 201    Loja 01              Celular ABXY            eletronicos
# 202    Loja 04                  Guitarra  instrumentos musicais
# 203    Loja 02         Jogo de tabuleiro             brinquedos
#
#      Quantidade de vendas
# 0                      65
# 1                      62
# 2                      62
# 3                      61
# 4                      60
# ..                    ...
# 199                    34
# 200                    33
# 201                    33
# 202                    33
# 203                    32
#
# [204 rows x 4 columns]

# %% [markdown]
# ### Capturando os produtos mais vendidos de cada loja pelo ID

# %%
produtos_mais_vendidos_loja1 = produtos_mais_vendidos_por_id.query('`ID da Loja` == "Loja 01"')
produtos_mais_vendidos_loja1
# Out:
#     ID da Loja                      Produto   Categoria do Produto  \
# 4      Loja 01                TV Led UHD 4K            eletronicos
# 5      Loja 01                  Micro-ondas       eletrodomesticos
# 6      Loja 01                Guarda roupas                 moveis
# 8      Loja 01           Secadora de roupas       eletrodomesticos
# 16     Loja 01             Blocos de montar             brinquedos
# 18     Loja 01                       Cômoda                 moveis
# 21     Loja 01             Bola de basquete        esporte e lazer
# 27     Loja 01                 Copo térmico        esporte e lazer
# 28     Loja 01                    Bicicleta        esporte e lazer
# 32     Loja 01                    Geladeira       eletrodomesticos
# 33     Loja 01                   Impressora            eletronicos
# 36     Loja 01                      Bateria  instrumentos musicais
# 39     Loja 01     Carrinho controle remoto             brinquedos
# 43     Loja 01                     Faqueiro  utilidades domesticas
# 48     Loja 01          Modelagem preditiva                 livros
# 58     Loja 01               Fone de ouvido            eletronicos
# 59     Loja 01             Celular Plus X42            eletronicos
# 61     Loja 01            Xadrez de madeira             brinquedos
# 65     Loja 01                  Lava louças       eletrodomesticos
# 83     Loja 01           Lavadora de roupas       eletrodomesticos
# 84     Loja 01                     Guitarra  instrumentos musicais
# 90     Loja 01        Cadeira de escritório                 moveis
# 92     Loja 01                       Violão  instrumentos musicais
# 93     Loja 01                Sofá retrátil                 moveis
# 106    Loja 01                        Fogão       eletrodomesticos
# 124    Loja 01                    Cama king                 moveis
# 125    Loja 01                     Cama box                 moveis
# 128    Loja 01                Kit banquetas                 moveis
# 129    Loja 01               Mesa de centro                 moveis
# 130    Loja 01                     Smart TV            eletronicos
# 131    Loja 01              Cubo mágico 8x8             brinquedos
# 137    Loja 01                   Smartwatch            eletronicos
# 138    Loja 01            Jogo de tabuleiro             brinquedos
# 139    Loja 01              Jogo de panelas  utilidades domesticas
# 146    Loja 01                Bola de vôlei        esporte e lazer
# 154    Loja 01                  Tablet ABXY            eletronicos
# 155    Loja 01      Dashboards com Power BI                 livros
# 157    Loja 01     Iniciando em programação                 livros
# 159    Loja 01                     Poltrona                 moveis
# 160    Loja 01                Jogo de copos  utilidades domesticas
# 164    Loja 01           Assistente virtual            eletronicos
# 165    Loja 01                  Boneca bebê             brinquedos
# 166    Loja 01               Corda de pular        esporte e lazer
# 170    Loja 01               Mesa de jantar                 moveis
# 171    Loja 01               Dinossauro Rex             brinquedos
# 176    Loja 01  Ciência de dados com python                 livros
# 177    Loja 01                      Mochila        esporte e lazer
# 191    Loja 01                     Pandeiro  instrumentos musicais
# 194    Loja 01            Panela de pressão  utilidades domesticas
# 200    Loja 01                      Headset            eletronicos
# 201    Loja 01                 Celular ABXY            eletronicos
#
#      Quantidade de vendas
# 4                      60
# 5                      60
# 6                      60
# 8                      58
# 16                     56
# 18                     56
# 21                     55
# 27                     54
# 28                     54
# 32                     54
# 33                     54
# 36                     53
# 39                     52
# 43                     52
# 48                     51
# 58                     50
# 59                     49
# 61                     49
# 65                     48
# 83                     47
# 84                     47
# 90                     46
# 92                     46
# 93                     46
# 106                    45
# 124                    44
# 125                    44
# 128                    44
# 129                    44
# 130                    44
# 131                    44
# 137                    43
# 138                    43
# 139                    43
# 146                    42
# 154                    42
# 155                    42
# 157                    41
# 159                    41
# 160                    41
# 164                    40
# 165                    40
# 166                    40
# 170                    40
# 171                    40
# 176                    39
# 177                    39
# 191                    36
# 194                    35
# 200                    33
# 201                    33

# %%
produtos_mais_vendidos_loja2 = produtos_mais_vendidos_por_id.query('`ID da Loja` == "Loja 02"')
produtos_mais_vendidos_loja2
# Out:
#     ID da Loja                      Produto   Categoria do Produto  \
# 0      Loja 02     Iniciando em programação                 livros
# 1      Loja 02                  Micro-ondas       eletrodomesticos
# 3      Loja 02                      Bateria  instrumentos musicais
# 9      Loja 02                       Violão  instrumentos musicais
# 10     Loja 02                     Pandeiro  instrumentos musicais
# 11     Loja 02           Secadora de roupas       eletrodomesticos
# 19     Loja 02             Celular Plus X42            eletronicos
# 26     Loja 02                Guarda roupas                 moveis
# 34     Loja 02             Blocos de montar             brinquedos
# 42     Loja 02              Jogo de panelas  utilidades domesticas
# 57     Loja 02               Corda de pular        esporte e lazer
# 60     Loja 02        Cadeira de escritório                 moveis
# 62     Loja 02           Lavadora de roupas       eletrodomesticos
# 63     Loja 02                    Geladeira       eletrodomesticos
# 67     Loja 02                  Boneca bebê             brinquedos
# 80     Loja 02                 Copo térmico        esporte e lazer
# 81     Loja 02                     Guitarra  instrumentos musicais
# 82     Loja 02     Carrinho controle remoto             brinquedos
# 85     Loja 02                     Cama box                 moveis
# 91     Loja 02                Bola de vôlei        esporte e lazer
# 103    Loja 02                  Lava louças       eletrodomesticos
# 104    Loja 02          Modelagem preditiva                 livros
# 105    Loja 02                Jogo de copos  utilidades domesticas
# 107    Loja 02                    Cama king                 moveis
# 109    Loja 02            Xadrez de madeira             brinquedos
# 110    Loja 02               Mesa de centro                 moveis
# 111    Loja 02                      Mochila        esporte e lazer
# 115    Loja 02              Cubo mágico 8x8             brinquedos
# 116    Loja 02                Kit banquetas                 moveis
# 118    Loja 02                    Bicicleta        esporte e lazer
# 119    Loja 02                TV Led UHD 4K            eletronicos
# 120    Loja 02            Panela de pressão  utilidades domesticas
# 121    Loja 02                Sofá retrátil                 moveis
# 123    Loja 02                      Headset            eletronicos
# 126    Loja 02                  Tablet ABXY            eletronicos
# 133    Loja 02                   Smartwatch            eletronicos
# 134    Loja 02                       Cômoda                 moveis
# 136    Loja 02      Dashboards com Power BI                 livros
# 145    Loja 02  Ciência de dados com python                 livros
# 148    Loja 02               Dinossauro Rex             brinquedos
# 150    Loja 02                        Fogão       eletrodomesticos
# 153    Loja 02             Bola de basquete        esporte e lazer
# 161    Loja 02                 Celular ABXY            eletronicos
# 169    Loja 02                     Smart TV            eletronicos
# 178    Loja 02                     Faqueiro  utilidades domesticas
# 187    Loja 02           Assistente virtual            eletronicos
# 188    Loja 02               Fone de ouvido            eletronicos
# 196    Loja 02                     Poltrona                 moveis
# 197    Loja 02               Mesa de jantar                 moveis
# 199    Loja 02                   Impressora            eletronicos
# 203    Loja 02            Jogo de tabuleiro             brinquedos
#
#      Quantidade de vendas
# 0                      65
# 1                      62
# 3                      61
# 9                      58
# 10                     58
# 11                     57
# 19                     55
# 26                     54
# 34                     54
# 42                     52
# 57                     50
# 60                     49
# 62                     49
# 63                     49
# 67                     48
# 80                     47
# 81                     47
# 82                     47
# 85                     47
# 91                     46
# 103                    46
# 104                    46
# 105                    46
# 107                    45
# 109                    45
# 110                    45
# 111                    45
# 115                    45
# 116                    45
# 118                    45
# 119                    45
# 120                    44
# 121                    44
# 123                    44
# 126                    44
# 133                    44
# 134                    44
# 136                    43
# 145                    43
# 148                    42
# 150                    42
# 153                    42
# 161                    41
# 169                    40
# 178                    39
# 187                    38
# 188                    37
# 196                    35
# 197                    34
# 199                    34
# 203                    32

# %%
produtos_mais_vendidos_loja3 = produtos_mais_vendidos_por_id.query('`ID da Loja` == "Loja 03"')
produtos_mais_vendidos_loja3
# Out:
#     ID da Loja                      Produto   Categoria do Produto  \
# 12     Loja 03                Kit banquetas                 moveis
# 13     Loja 03                    Cama king                 moveis
# 17     Loja 03               Mesa de jantar                 moveis
# 20     Loja 03                       Cômoda                 moveis
# 23     Loja 03              Jogo de panelas  utilidades domesticas
# 30     Loja 03                     Smart TV            eletronicos
# 35     Loja 03                        Fogão       eletrodomesticos
# 37     Loja 03          Modelagem preditiva                 livros
# 38     Loja 03               Corda de pular        esporte e lazer
# 40     Loja 03                    Bicicleta        esporte e lazer
# 41     Loja 03            Jogo de tabuleiro             brinquedos
# 44     Loja 03     Carrinho controle remoto             brinquedos
# 46     Loja 03                  Lava louças       eletrodomesticos
# 47     Loja 03                     Pandeiro  instrumentos musicais
# 51     Loja 03                   Impressora            eletronicos
# 52     Loja 03             Bola de basquete        esporte e lazer
# 53     Loja 03                    Geladeira       eletrodomesticos
# 64     Loja 03                Guarda roupas                 moveis
# 72     Loja 03                Bola de vôlei        esporte e lazer
# 73     Loja 03                  Tablet ABXY            eletronicos
# 76     Loja 03            Xadrez de madeira             brinquedos
# 77     Loja 03                       Violão  instrumentos musicais
# 88     Loja 03                     Poltrona                 moveis
# 89     Loja 03            Panela de pressão  utilidades domesticas
# 94     Loja 03     Iniciando em programação                 livros
# 95     Loja 03               Dinossauro Rex             brinquedos
# 98     Loja 03  Ciência de dados com python                 livros
# 99     Loja 03             Celular Plus X42            eletronicos
# 100    Loja 03                     Cama box                 moveis
# 101    Loja 03        Cadeira de escritório                 moveis
# 102    Loja 03                   Smartwatch            eletronicos
# 114    Loja 03                Sofá retrátil                 moveis
# 117    Loja 03           Secadora de roupas       eletrodomesticos
# 127    Loja 03              Cubo mágico 8x8             brinquedos
# 132    Loja 03                 Celular ABXY            eletronicos
# 144    Loja 03               Fone de ouvido            eletronicos
# 147    Loja 03                TV Led UHD 4K            eletronicos
# 149    Loja 03               Mesa de centro                 moveis
# 151    Loja 03           Lavadora de roupas       eletrodomesticos
# 158    Loja 03                      Bateria  instrumentos musicais
# 162    Loja 03      Dashboards com Power BI                 livros
# 174    Loja 03                     Faqueiro  utilidades domesticas
# 179    Loja 03           Assistente virtual            eletronicos
# 180    Loja 03                  Boneca bebê             brinquedos
# 181    Loja 03                      Headset            eletronicos
# 185    Loja 03                     Guitarra  instrumentos musicais
# 186    Loja 03                 Copo térmico        esporte e lazer
# 190    Loja 03                Jogo de copos  utilidades domesticas
# 192    Loja 03                      Mochila        esporte e lazer
# 193    Loja 03                  Micro-ondas       eletrodomesticos
# 195    Loja 03             Blocos de montar             brinquedos
#
#      Quantidade de vendas
# 12                     57
# 13                     56
# 17                     56
# 20                     55
# 23                     55
# 30                     54
# 35                     53
# 37                     53
# 38                     53
# 40                     52
# 41                     52
# 44                     52
# 46                     52
# 47                     51
# 51                     50
# 52                     50
# 53                     50
# 64                     49
# 72                     48
# 73                     48
# 76                     47
# 77                     47
# 88                     47
# 89                     47
# 94                     46
# 95                     46
# 98                     46
# 99                     46
# 100                    46
# 101                    46
# 102                    46
# 114                    45
# 117                    45
# 127                    44
# 132                    44
# 144                    43
# 147                    42
# 149                    42
# 151                    42
# 158                    41
# 162                    40
# 174                    39
# 179                    39
# 180                    39
# 181                    39
# 185                    38
# 186                    38
# 190                    36
# 192                    36
# 193                    36
# 195                    35

# %%
produtos_mais_vendidos_loja4 = produtos_mais_vendidos_por_id.query('`ID da Loja` == "Loja 04"')
produtos_mais_vendidos_loja4
# Out:
#     ID da Loja                      Produto   Categoria do Produto  \
# 2      Loja 04                     Cama box                 moveis
# 7      Loja 04                     Faqueiro  utilidades domesticas
# 14     Loja 04                    Cama king                 moveis
# 15     Loja 04      Dashboards com Power BI                 livros
# 22     Loja 04     Carrinho controle remoto             brinquedos
# 24     Loja 04               Mesa de jantar                 moveis
# 25     Loja 04                       Cômoda                 moveis
# 29     Loja 04                     Smart TV            eletronicos
# 31     Loja 04             Blocos de montar             brinquedos
# 45     Loja 04                     Pandeiro  instrumentos musicais
# 49     Loja 04              Jogo de panelas  utilidades domesticas
# 50     Loja 04                   Impressora            eletronicos
# 54     Loja 04           Assistente virtual            eletronicos
# 55     Loja 04             Bola de basquete        esporte e lazer
# 56     Loja 04          Modelagem preditiva                 livros
# 66     Loja 04            Jogo de tabuleiro             brinquedos
# 68     Loja 04                  Boneca bebê             brinquedos
# 69     Loja 04                Bola de vôlei        esporte e lazer
# 70     Loja 04             Celular Plus X42            eletronicos
# 71     Loja 04                 Copo térmico        esporte e lazer
# 74     Loja 04                      Bateria  instrumentos musicais
# 75     Loja 04                  Micro-ondas       eletrodomesticos
# 78     Loja 04               Dinossauro Rex             brinquedos
# 79     Loja 04              Cubo mágico 8x8             brinquedos
# 86     Loja 04                Sofá retrátil                 moveis
# 87     Loja 04                        Fogão       eletrodomesticos
# 96     Loja 04            Panela de pressão  utilidades domesticas
# 97     Loja 04                Jogo de copos  utilidades domesticas
# 108    Loja 04                  Tablet ABXY            eletronicos
# 112    Loja 04                    Bicicleta        esporte e lazer
# 113    Loja 04                     Poltrona                 moveis
# 122    Loja 04               Mesa de centro                 moveis
# 135    Loja 04               Fone de ouvido            eletronicos
# 140    Loja 04                      Mochila        esporte e lazer
# 141    Loja 04                  Lava louças       eletrodomesticos
# 142    Loja 04               Corda de pular        esporte e lazer
# 143    Loja 04     Iniciando em programação                 livros
# 152    Loja 04                      Headset            eletronicos
# 156    Loja 04                Kit banquetas                 moveis
# 163    Loja 04        Cadeira de escritório                 moveis
# 167    Loja 04           Secadora de roupas       eletrodomesticos
# 168    Loja 04                TV Led UHD 4K            eletronicos
# 172    Loja 04                   Smartwatch            eletronicos
# 173    Loja 04            Xadrez de madeira             brinquedos
# 175    Loja 04                 Celular ABXY            eletronicos
# 182    Loja 04  Ciência de dados com python                 livros
# 183    Loja 04                    Geladeira       eletrodomesticos
# 184    Loja 04           Lavadora de roupas       eletrodomesticos
# 189    Loja 04                       Violão  instrumentos musicais
# 198    Loja 04                Guarda roupas                 moveis
# 202    Loja 04                     Guitarra  instrumentos musicais
#
#      Quantidade de vendas
# 2                      62
# 7                      59
# 14                     56
# 15                     56
# 22                     55
# 24                     55
# 25                     55
# 29                     54
# 31                     54
# 45                     52
# 49                     50
# 50                     50
# 54                     50
# 55                     50
# 56                     50
# 66                     48
# 68                     48
# 69                     48
# 70                     48
# 71                     48
# 74                     48
# 75                     48
# 78                     47
# 79                     47
# 86                     47
# 87                     47
# 96                     46
# 97                     46
# 108                    45
# 112                    45
# 113                    45
# 122                    44
# 135                    44
# 140                    43
# 141                    43
# 142                    43
# 143                    43
# 152                    42
# 156                    42
# 163                    40
# 167                    40
# 168                    40
# 172                    39
# 173                    39
# 175                    39
# 182                    38
# 183                    38
# 184                    38
# 189                    37
# 198                    34
# 202                    33

# %% [markdown]
# ## Visualizando os produtos mais e menos vendidos
#
# Vamos visualizar as categorias mais vendidas, considerando todas as lojas, e em seguida, vamos visualizar especificamente os produtos mais e menos vendidos de cada loja.
# Para uma melhor visualização, vamos visualizar os 5 produtos mais vendidos e os 5 produtos menos vendidos de cada loja

# %% [markdown]
# ### Produtos mais e menos vendidos por categoria, no total

# %%
categorias_mais_vendidas_total.columns
# Out:
# Index(['Categoria do Produto', 'Quantidade de Vendas'], dtype='object')

# %%
fig = px.pie(
    categorias_mais_vendidas_total,
    values='Quantidade de Vendas',
    names='Categoria do Produto',
    color='Categoria do Produto',
    title='Categorias mais vendidas entre as 4 lojas, no total',
    width=1000, height=500
)

fig.update_layout(legend_title_text='Categorias')
fig.update_traces(textinfo='percent+value')

fig.show()

# %% [markdown]
# ### Top 5 produtos mais e menos vendidos de cada loja

# %% [markdown]
# #### Loja 1

# %%
top5_mais_menos_vendidos_loja1 = pd.concat([produtos_mais_vendidos_loja1.head(), produtos_mais_vendidos_loja1.tail()], ignore_index=True)
top5_mais_menos_vendidos_loja1 = top5_mais_menos_vendidos_loja1.sort_values(by='Quantidade de vendas', ascending=False)


fig = px.bar(top5_mais_menos_vendidos_loja1,
             x='Produto', y='Quantidade de vendas',
             hover_data=['Categoria do Produto'],
             labels=({'Categoria do Produto': 'Categoria do Produto'}),
             title='Top 5 Produtos mais e menos vendidos (Loja 1)',
             color='Categoria do Produto',
             height=600,
             category_orders={
                'Produto': top5_mais_menos_vendidos_loja1['Produto'].tolist()
             }
            )

fig.show()

# %% [markdown]
# #### Loja 2

# %%
top5_mais_menos_vendidos_loja2 = pd.concat([produtos_mais_vendidos_loja2.head(), produtos_mais_vendidos_loja2.tail()], ignore_index=True)
top5_mais_menos_vendidos_loja2 = top5_mais_menos_vendidos_loja2.sort_values(by='Quantidade de vendas', ascending=False)


fig = px.bar(top5_mais_menos_vendidos_loja2,
             x='Produto', y='Quantidade de vendas',
             hover_data=['Categoria do Produto'],
             labels=({'Categoria do Produto': 'Categoria do Produto'}),
             title='Top 5 Produtos mais e menos vendidos (Loja 2)',
             color='Categoria do Produto',
             height=600,
             category_orders={
                'Produto': top5_mais_menos_vendidos_loja2['Produto'].tolist()
             }
            )

fig.show()

# %% [markdown]
# #### Loja 3

# %%
top5_mais_menos_vendidos_loja3 = pd.concat([produtos_mais_vendidos_loja3.head(), produtos_mais_vendidos_loja3.tail()], ignore_index=True)
top5_mais_menos_vendidos_loja3 = top5_mais_menos_vendidos_loja3.sort_values(by='Quantidade de vendas', ascending=False)


fig = px.bar(top5_mais_menos_vendidos_loja3,
             x='Produto', y='Quantidade de vendas',
             hover_data=['Categoria do Produto'],
             labels=({'Categoria do Produto': 'Categoria do Produto'}),
             title='Top 5 Produtos mais e menos vendidos (Loja 3)',
             color='Categoria do Produto',
             height=600,
             category_orders={
                'Produto': top5_mais_menos_vendidos_loja3['Produto'].tolist()
             }
            )

fig.show()

# %% [markdown]
# #### Loja 4

# %%
top5_mais_menos_vendidos_loja4 = pd.concat([produtos_mais_vendidos_loja4.head(), produtos_mais_vendidos_loja4.tail()], ignore_index=True)
top5_mais_menos_vendidos_loja4 = top5_mais_menos_vendidos_loja4.sort_values(by='Quantidade de vendas', ascending=False)

fig = px.bar(top5_mais_menos_vendidos_loja4,
             x='Produto', y='Quantidade de vendas',
             hover_data=['Categoria do Produto'],
             labels=({'Categoria do Produto': 'Categoria do Produto'}),
             title='Top 5 Produtos mais e menos vendidos (Loja 4)',
             color='Categoria do Produto',
             height=600,
             category_orders={
                'Produto': top5_mais_menos_vendidos_loja4['Produto'].tolist()
             }
            )

fig.show()

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
lojas.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon ID da Loja
# 0    cartao_credito                       8 -22.19 -48.79    Loja 01
# 1    cartao_credito                       4 -22.25 -42.66    Loja 01
# 2    cartao_credito                       1 -15.83 -47.86    Loja 01
# 3            boleto                       1 -30.17 -53.50    Loja 01
# 4            boleto                       1 -18.10 -44.38    Loja 01

# %% [markdown]
# > Vamos lembrar que, com base na nossa análise estatística no início do projeto, o `Frete` está em Reais normais, ou seja, não está nem em milhares e nem em apenas centavos.

# %% [markdown]
# ## Frete médio de todas as lojas juntas, no total

# %%
lojas['Frete'].mean()
# Out:
# np.float64(33.16700181769606)

# %% [markdown]
# ## Frete médio de cada loja, separadamente

# %%
frete_medio_loja1 = loja.Frete.mean()
frete_medio_loja2 = loja2.Frete.mean()
frete_medio_loja3 = loja3.Frete.mean()
frete_medio_loja4 = loja4.Frete.mean()

print(f'''
FRETE MÉDIO DE CADA LOJA

- Loja 01: R${frete_medio_loja1:.2f};
- Loja 02: R${frete_medio_loja2:.2f};
- Loja 03: R${frete_medio_loja3:.2f};
- Loja 04: R${frete_medio_loja4:.2f}.
''')
# Out:
# FRETE MÉDIO DE CADA LOJA
#
# - Loja 01: R$34.69;
# - Loja 02: R$33.62;
# - Loja 03: R$33.07;
# - Loja 04: R$31.28.

# %% [markdown]
# ## Visualizando o frete médio de cada loja

# %%
frete_medio_todas_as_lojas = lojas.groupby('ID da Loja')['Frete'].mean().sort_values(ascending=False).reset_index()
frete_medio_todas_as_lojas['Frete (arredondado)'] = frete_medio_todas_as_lojas['Frete'].round(2)
frete_medio_todas_as_lojas
# Out:
#   ID da Loja      Frete  Frete (arredondado)
# 0    Loja 01  34.691805                34.69
# 1    Loja 02  33.621941                33.62
# 2    Loja 03  33.074464                33.07
# 3    Loja 04  31.278997                31.28

# %%
fig = px.bar(frete_medio_todas_as_lojas,
             x='ID da Loja',
             y='Frete',
             title='Frete médio de cada loja (em R$)',
             text='Frete (arredondado)'
            )

fig.show()

# %% [markdown]
# > A loja 01, que possui a maior parte do faturamento, também possui o maio preço médio de frete.
#
# > As lojas 02 e 03, que possuem um faturamento intermediário, seguem a mesma linha, com valor de frete também médio.
#
# > A loja 04, que possui o menor faturamento, também possui o menor preço de frete

# %% [markdown]
# ---
#
# # Relatório final

# %% [markdown]
# ## Recapitulando o problema de negócio:
# Você foi contratado como pessoa analista de dados para ajudar Sr. João a decidir **qual loja ele deve vender.**
#
# O Sr. João tem uma rede de quatro lojas, que pertencem ao e-commerce Alura Store. Ele quer vender uma dessas lojas para ter um capital e investir em um novo negócio.
#
# Você, como pessoa analista de dados, vai **analisar qual dessas lojas tem o menor desempenho comparado às outras e, baseado nisso, fazer um relatório e mostrar para Sr.João qual loja ele deve vender.**
#
# Para isso, você vai analisar as seguintes métricas: `faturamento total de cada loja`, `categorias mais populares`, `média de avaliação dos clientes`, `produtos mais e menos vendidos` e `custo médio do frete`.
#
# Com essas métricas, você será capaz de decidir qual loja Sr.João deve vender.
#
# ## Faturamento total de cada loja
#
# O faturamento é a principal métrica a ser analisada e que terá maior peso na avaliação de qual loja deve ser vendida.
#
# O faturamento por loja, em milhões de reais (R$) foi de:
#
# **- Loja 01:** `R$1.535M`
#
# **- Loja 02:** `R$1.488M`
#
# **- Loja 03:** `R$1.464M`
#
# **- Loja 04:** `R$1.384M`
#
# Abaixo, segue o gráfico de faturamento por loja:
# ![Faturamento por loja.png](attachment:7a634257-7de8-4379-bd34-78057b97fb32.png)
#
# Podemos concluir com essa análise que:
# - A **Loja 01 possui maior faturamento**
# - Por outro lado, **Loja 04 possui o menor faturamento**.
#
# ## Vendas por categoria
#
# As vendas por categoria nos ajudam a identificar quais são as categorias mais e menos compradas em cada loja.
#
# Abaixo, segue o gráfico de vendas por categoria de cada loja:
# ![Vendas por categoria.png](attachment:407cf2d0-2788-4680-b2ab-a2c816f3fcb0.png)
# ![Vendas por categoria - Setores.png](attachment:c8a20853-66e1-40b6-8646-7473e094f507.png)
#
# Com base nas análises, obtemos chegar às seguintes conclusões:
# - Em todas as lojas, a categoria de **móveis foi a mais vendida**, totalizando a quantidade de 1886 vendas, o que representa 20% do total de vendas por categoria em todas as lojas.
#
# - Seguido da categoria de móveis, temos a categoria de **eletrônicos**, que é a segunda mais vendida, contabilizando 1772 vendas e representando 18.8% do total de vendas.
#
# - Em todas as lojas, a categoria de brinquedos foi procurada e obteve uma quantidade de vendas superior à 300. Partindo do ponto que a maior quantidade de vendas registrada entre todas as lojas foi de 499, **a categoria de brinquedos apresenta um bom desempenho nas vendas, ocupando portanto a terceira posição no ranking de categorias mais procuradas.**
#
# - Em todas as lojas, as categorias **Utilidades domésticas**, **Instrumentos musicais** e **Livros** apresentaram uma quantidade de vendas abaixo de 250, sendo essas **as categorias menos procuradas em todas as lojas.**
#
# ## Média de avaliação das lojas
#
# As médias de avaliação das lojas representam a satisfação dos clientes em cada loja.
#
# As médias, de 1 a 5, foram, respectivamente:
#
# - **Loja 03:** `4.05`
# - **Loja 02:** `4.04`
# - **Loja 04:** `4.00`
# - **Loja 01:** `3.98`
#
# Pode-se perceber, com essa análise, que:
# - A **Loja 3 possui uma maior avaliação**
# - A **Loja 01, responsável pelo maior faturamento dentre todas as lojas do Sr.João, é que possui pior avaliação.**
# - A **Loja 04, de menor faturamento, apresenta uma média de avaliações razoável**, não estando nem alta como as médias das lojas 03 e 02, e nem muito baixa como a avaliação da loja 01.
#
# ## Produtos mais e menos vendidos por loja
#
# Seguem abaixo os gráficos dos 5 produtos mais e menos vendidos de cada loja:
#
# ![image.png](attachment:4ffc453a-a522-44c5-9675-93bb2814f048.png)
#
# ![image.png](attachment:0e83ced8-f4ea-431c-93a6-85e73fd05448.png)
#
# ![image.png](attachment:ce1d56a1-9738-4068-8f1f-b7622856074d.png)
#
# ![image.png](attachment:48e7e31d-5c11-4467-a365-1f920600a146.png)
#
# ## Frete médio por loja
#
# Segue abaixo o gráfico do preço médio de frete por loja:
# ![Frete médio.png](attachment:7d9c28ed-4675-430f-b6af-3d31633e6d46.png)
#
# Podemos concluir, com a visualização, que:
# - A **loja 01**, que possui a maior parte do faturamento, também **possui o maior preço médio de frete**.
#
# - As lojas 02 e 03, que possuem um faturamento intermediário, seguem a mesma linha, com valor de frete também médio.
#
# - A **loja 04**, que possui o menor faturamento, também possui o **menor preço de frete.**
#
#
# ## Qual loja deve ser vendida?
#
# ### Cenário 01 - Venda da pior faturamento:
# Com base nos dados analisados, podemos perceber que a `Loja 04` é a que possui menor faturamento e média de avaliações razoável. O seu frete médio é baixo, mas isso possivelmente se deve à baixa quantidade de vendas e faturamento da loja.
#
# Diante desse desempenho abaixo, pode-se concluir que a venda da Loja 4 seria um ótimo negócio, visto que traria lucro pela sua venda, principalmente levando em consideração o desempenho da loja ao nos últimos tempos em faturamento.
#
# ### Cenário 02 - Venda de uma das lojas de faturamento intermediário:
# As `Lojas 02 e 03` possuem as melhores avaliações, com ambas tendo médias de avaliação extremamente próximas, faturamentos intermediários e preços de frete também intermediários.
#
# Tendo em vista que ambas as lojas possuem uma boa percepção do cliente, com base nas avaliações, apresentam valores de faturamento parecidos e um preço de frete que não é extremamente alto, a venda de uma dessas lojas viria a ser um bom negócio, com preferência para a venda da Loja 3.
#
# A escolha da Loja 3 se dá pois a loja apresenta um faturamento menor, embora parecido, com o da Loja 02, e uma avaliação semelhante com a da Loja 02 (com ambos tendo uma diferença de apenas 0.01 em suas médias de avaliação). Além disso, a sua venda poderia vir a subir a quantidade de vendas de produtos da categoria de móveis nas demais lojas, o que poderia aumentar consequentemente os faturamentos.
#
# ### Visão geral dos possíveis cenários
#
# **Venda da Loja 04:**
# - É a loja com pior desempenho em faturamento;
# - Possui uma média de avaliações razoável, não sendo nem a pior e nem uma das melhores;
# - Sua venda traria o fortalecimento das demais lojas, e ainda traria um alívio quanto às despesas;
# - É a escolha de venda mais segura.
#
# **Venda da Loja 03:**
# - Dentre as lojas intermediárias (Loja 2 e Loja 3), é a que possui o menor faturamento;
# - Embora possua uma nota mais alta (4.05), a sua média de avaliações é muito próxima da média da Loja 2 (4.04), que também é uma média alta;
# - Sua venda traria fortalecimento quanto aos produtos vendidos nas demais lojas, visto que, com sua venda, a tendência é que as vendas de imóveis nas demais lojas aumentem;
#
# ### Recomendação final
#
# Como recomendação final, a escolha mais secura é a venda da loja 4, pois é a que possui o pior faturamento e consequentemente o menor impacto na receita total. Além disso, a sua venda iria reduzir despesas quanto à operação da loja no geral.
